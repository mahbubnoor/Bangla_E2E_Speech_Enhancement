# %% [markdown]
# <a href="https://www.kaggle.com/code/mdmahbubenoor/notebookd7610a3820?scriptVersionId=316236572" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## 🔧 Code Repository
#
# The complete implementation for Bangla end-to-end speech enhancement is available here:
#
# 👉 https://github.com/mahbubnoor/Bangla_E2E_Speech_Enhancement
#
# **Includes:**
# - Data preprocessing pipeline
# - Speech enhancement models
# - Training and evaluation scripts
#
# > This notebook demonstrates how to use the dataset with the above implementation.
